# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Data/demo_data.csv')
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.head(1)
# Out:
#    age  workclass  fnlwgt  education  education-num marital-status  \
# 0   39  State-gov   77516  Bachelors             13  Never-married
#
#      occupation   relationship   race   sex  capital-gain  capital-loss  \
# 0  Adm-clerical  Not-in-family  White  Male          2174             0
#
#    hours-per-week native-country salary
# 0              40  United-States  <=50K

# %%
df.tail()
# Out:
#        age     workclass  fnlwgt   education  education-num  \
# 32556   27       Private  257302  Assoc-acdm             12
# 32557   40       Private  154374     HS-grad              9
# 32558   58       Private  151910     HS-grad              9
# 32559   22       Private  201490     HS-grad              9
# 32560   52  Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation relationship   race     sex  \
# 32556  Married-civ-spouse       Tech-support         Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 32558             Widowed       Adm-clerical    Unmarried  White  Female
# 32559       Never-married       Adm-clerical    Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 32556             0             0              38  United-States  <=50K
# ...

# %%
df.tail(4)
# Out:
#        age     workclass  fnlwgt education  education-num      marital-status  \
# 32557   40       Private  154374   HS-grad              9  Married-civ-spouse
# 32558   58       Private  151910   HS-grad              9             Widowed
# 32559   22       Private  201490   HS-grad              9       Never-married
# 32560   52  Self-emp-inc  287927   HS-grad              9  Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 32557  Machine-op-inspct      Husband  White    Male             0
# 32558       Adm-clerical    Unmarried  White  Female             0
# 32559       Adm-clerical    Own-child  White    Male             0
# 32560    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country salary
# 32557             0              40  United-States   >50K
# 32558             0              40  United-States  <=50K
# 32559             0              20  United-States  <=50K
# ...

# %%
df.sample(4)
# Out:
#        age workclass  fnlwgt  education  education-num      marital-status  \
# 4128    23   Private  202344  Bachelors             13       Never-married
# 21482   30   Private  116138  Bachelors             13       Never-married
# 17900   52   Private   31460    HS-grad              9            Divorced
# 1800    28   Private  186792  Bachelors             13  Married-civ-spouse
#
#             occupation   relationship   race     sex  capital-gain  \
# 4128    Prof-specialty      Own-child  White  Female             0
# 21482  Exec-managerial  Not-in-family  White    Male         27828
# 17900    Other-service  Not-in-family  White    Male             0
# 1800      Adm-clerical        Husband  White    Male             0
#
#        capital-loss  hours-per-week native-country salary
# 4128              0              40  United-States  <=50K
# 21482             0              60  United-States   >50K
# 17900             0              38  United-States  <=50K
# ...

# %%
df.sample(frac=0.0002)
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 24683   45       Federal-gov  201127  Some-college             10
# 22900   46           Private  124733  Some-college             10
# 25700   27           Private  194243   Prof-school             15
# 14209   62           Private  244933       Masters             14
# 10111   29           Private  184596          11th              7
# 31155   31  Self-emp-not-inc   44503  Some-college             10
# 2167    45           Private  242391     Bachelors             13
#
#            marital-status       occupation   relationship                race  \
# 24683  Married-civ-spouse   Prof-specialty        Husband               White
# 22900  Married-civ-spouse     Craft-repair        Husband  Asian-Pac-Islander
# 25700       Never-married   Prof-specialty      Own-child               White
# 14209            Divorced   Prof-specialty  Not-in-family               White
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df['capital-gain'].value_counts()
# Out:
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 1111         1
# 2538         1
# 22040        1
# 4931         1
# 5060         1
# Name: capital-gain, Length: 119, dtype: int64

# %%
df['capital-gain'].value_counts(normalize=True) * 100
# Out:
# 0        91.671017
# 15024     1.065692
# 7688      0.872209
# 7298      0.755505
# 99999     0.488314
#            ...
# 1111      0.003071
# 2538      0.003071
# 22040     0.003071
# 4931      0.003071
# 5060      0.003071
# Name: capital-gain, Length: 119, dtype: float64

# %%
df['capital-loss'].value_counts(normalize=True)
# Out:
# 0       0.953349
# 1902    0.006204
# 1977    0.005160
# 1887    0.004883
# 1848    0.001566
#           ...
# 2080    0.000031
# 1539    0.000031
# 1844    0.000031
# 2489    0.000031
# 1411    0.000031
# Name: capital-loss, Length: 92, dtype: float64

# %% [markdown]
# ### 1. How many people of each race are represented?

# %%
df.race.value_counts()
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %% [markdown]
# ### 2. What is the average age of men?

# %%
df[df.sex == 'Male']['age'].mean().round(1)
# Out:
# 39.4

# %% [markdown]
# ### 3. What is the percentage of people who have a Bachelor's degree?

# %%
round(df.education.value_counts(normalize=True)['Bachelors'] * 100, 1)
# Out:
# 16.4

# %%
round(df[df.education == 'Bachelors'].shape[0] / len(df) * 100, 1)
# Out:
# 16.4

# %% [markdown]
# ### 4. What percentage of people with advanced education (Bachelors, Masters or Doctorate) make more than 50K?

# %%
df.education.unique()
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
df.salary.unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
edu_dict = dict(zip(df.education.unique(), df['education-num'].unique()))
edu_dict
# Out:
# {'Bachelors': 13,
#  'HS-grad': 9,
#  '11th': 7,
#  'Masters': 14,
#  '9th': 5,
#  'Some-college': 10,
#  'Assoc-acdm': 12,
#  'Assoc-voc': 11,
#  '7th-8th': 4,
#  'Doctorate': 16,
#  'Prof-school': 15,
#  '5th-6th': 3,
#  '10th': 6,
#  '1st-4th': 2,
#  'Preschool': 1,
#  '12th': 8}

# %%
hedu_df = df[(df['education-num'] >= 13) & (df['education-num'] != 15)]
hedu_df.education.unique()
# Out:
# array(['Bachelors', 'Masters', 'Doctorate'], dtype=object)

# %%
round(hedu_df.salary.value_counts(normalize=True)['>50K'] * 100, 1)
# Out:
# 46.5

# %% [markdown]
# ### 5. What percentage of people without advanced education make more than 50K?

# %%
ledu_df = df[(df['education-num'] < 13) | (df['education-num'] == 15)]
ledu_df.education.unique()
# Out:
# array(['HS-grad', '11th', '9th', 'Some-college', 'Assoc-acdm',
#        'Assoc-voc', '7th-8th', 'Prof-school', '5th-6th', '10th',
#        '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
round(ledu_df.salary.value_counts(normalize=True)['>50K'] * 100, 1)
# Out:
# 17.4

# %% [markdown]
# ### 6. What is the minimum number of hours a person works per week?

# %%
df['hours-per-week'].min()
# Out:
# 1

# %% [markdown]
# ### 7. What percentage of the people who work the minimum number of hours per week have a salary of more than 50K?

# %%
minh_df = df[df['hours-per-week'] == df['hours-per-week'].min()]
minh_df.head()
# Out:
#       age     workclass  fnlwgt  education  education-num      marital-status  \
# 189    58     State-gov  109567  Doctorate             16  Married-civ-spouse
# 1036   66  Self-emp-inc  150726        9th              5  Married-civ-spouse
# 1262   69             ?  195779  Assoc-voc             11             Widowed
# 5590   78             ?  363134    HS-grad              9             Widowed
# 5632   45             ?  189564    Masters             14  Married-civ-spouse
#
#            occupation   relationship   race     sex  capital-gain  \
# 189    Prof-specialty        Husband  White    Male             0
# 1036  Exec-managerial        Husband  White    Male          1409
# 1262                ?  Not-in-family  White  Female             0
# 5590                ?  Not-in-family  White  Female             0
# 5632                ?           Wife  White  Female             0
#
#       capital-loss  hours-per-week native-country salary
# ...

# %%
minh_df.shape
# Out:
# (20, 15)

# %%
minh_df.salary.value_counts(normalize=True)['>50K'] * 100
# Out:
# 10.0

# %% [markdown]
# ### 8. What country has the highest percentage of people that earn >50K and what is that percentage?

# %%
hs_df = df[df.salary == '>50K']
hs_df.head()
# Out:
#     age         workclass  fnlwgt     education  education-num  \
# 7    52  Self-emp-not-inc  209642       HS-grad              9
# 8    31           Private   45781       Masters             14
# 9    42           Private  159449     Bachelors             13
# 10   37           Private  280464  Some-college             10
# 11   30         State-gov  141297     Bachelors             13
#
#         marital-status       occupation   relationship                race  \
# 7   Married-civ-spouse  Exec-managerial        Husband               White
# 8        Never-married   Prof-specialty  Not-in-family               White
# 9   Married-civ-spouse  Exec-managerial        Husband               White
# 10  Married-civ-spouse  Exec-managerial        Husband               Black
# 11  Married-civ-spouse   Prof-specialty        Husband  Asian-Pac-Islander
#
#        sex  capital-gain  capital-loss  hours-per-week native-country salary
# ...

# %%
salary_table = hs_df['native-country'].value_counts() / df['native-country'].value_counts()

# %%
salary_table.sort_values(ascending=False)
# Out:
# Iran                          0.418605
# France                        0.413793
# India                         0.400000
# Taiwan                        0.392157
# Japan                         0.387097
# Yugoslavia                    0.375000
# Cambodia                      0.368421
# Italy                         0.342466
# England                       0.333333
# Canada                        0.322314
# Germany                       0.321168
# Philippines                   0.308081
# Hong                          0.300000
# Greece                        0.275862
# China                         0.266667
# Cuba                          0.263158
# ?                             0.250429
# Scotland                      0.250000
# United-States                 0.245835
# Hungary                       0.230769
# Ireland                       0.208333
# South                         0.200000
# Poland                        0.200000
# Thailand                      0.166667
# ...

# %%
salary_table.max() * 100
# Out:
# 41.86046511627907

# %%
df[df['native-country'] == 'United-States']['salary'].value_counts(normalize=True)
# Out:
# <=50K    0.754165
# >50K     0.245835
# Name: salary, dtype: float64

# %% [markdown]
# ### 9. What is the most popular occupation for those who earn >50K in India?

# %%
df[(df.salary == '>50K') & (df['native-country'] == 'India')]['occupation'].value_counts()
# Out:
# Prof-specialty      25
# Exec-managerial      8
# Other-service        2
# Tech-support         2
# Transport-moving     1
# Sales                1
# Adm-clerical         1
# Name: occupation, dtype: int64

# %% [markdown]
# **Apply**

# %%
df.age.apply(np.sqrt)
# Out:
# 0        6.244998
# 1        7.071068
# 2        6.164414
# 3        7.280110
# 4        5.291503
#            ...
# 32556    5.196152
# 32557    6.324555
# 32558    7.615773
# 32559    4.690416
# 32560    7.211103
# Name: age, Length: 32561, dtype: float64

# %%
df.sex = df.sex.apply(lambda x: 'M' if x == 'Male' else 'F')

# %%
df.sample(7)
# Out:
#        age     workclass  fnlwgt     education  education-num  \
# 30785   24       Private  315476    Assoc-acdm             12
# 22273   61   Federal-gov  197311       Masters             14
# 3809    25       Private  197871  Some-college             10
# 10262   39       Private  233428       HS-grad              9
# 32196   41  Self-emp-inc   64506       HS-grad              9
# 3887    31             ?   26553     Bachelors             13
# 29874   63     Local-gov  214143     Bachelors             13
#
#            marital-status        occupation    relationship   race sex  \
# 30785       Never-married      Craft-repair       Own-child  White   M
# 22273             Widowed    Prof-specialty       Unmarried  White   F
# 3809   Married-civ-spouse             Sales         Husband  White   M
# 10262            Divorced   Exec-managerial  Other-relative  White   F
# 32196  Married-civ-spouse   Farming-fishing         Husband  White   M
# ...

# %%
def age_group(age):
    if 17 <= age <= 32:
        return 'Group 1'
    elif 33 <= age <= 46:
        return 'Group 2'
    elif 47 <= age <= 65:
        return 'Group 3'
    else:
        return 'Group 4'

# %%
df.age.apply(age_group).value_counts().plot(kind='bar', title='TITLE!')
# Out:
# <AxesSubplot: title={'center': 'TITLE!'}>

# %%
df.select_dtypes(exclude='object').head()
# Out:
#    age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40

# %%
df.select_dtypes(include='object').head(3)
# Out:
#           workclass  education      marital-status         occupation  \
# 0         State-gov  Bachelors       Never-married       Adm-clerical
# 1  Self-emp-not-inc  Bachelors  Married-civ-spouse    Exec-managerial
# 2           Private    HS-grad            Divorced  Handlers-cleaners
#
#     relationship   race sex native-country salary
# 0  Not-in-family  White   M  United-States  <=50K
# 1        Husband  White   M  United-States  <=50K
# 2  Not-in-family  White   M  United-States  <=50K

# %%
df.sort_values(by='age')
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 12318   17           Private  127366          11th              7
# 6312    17           Private  132755          11th              7
# 30927   17           Private  108470          11th              7
# 12787   17         Local-gov  308901          11th              7
# 25755   17                 ?   47407          11th              7
# ...    ...               ...     ...           ...            ...
# 24043   90  Self-emp-not-inc   82628       HS-grad              9
# 32277   90           Private  313749       HS-grad              9
# 5104    90           Private   52386  Some-college             10
# 8963    90                 ?   77053       HS-grad              9
# 10210   90  Self-emp-not-inc  282095  Some-college             10
#
#            marital-status       occupation   relationship                race  \
# 12318       Never-married            Sales      Own-child               White
# ...

# %%
df.sort_values(by='hours-per-week', ascending=False).head()
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 8654    30           Private  103596    HS-grad              9
# 15460   37           Private  241174  Bachelors             13
# 935     37           Private  176900    HS-grad              9
# 26250   36  Self-emp-not-inc  257250  Assoc-voc             11
# 16992   19           Private  121074    7th-8th              4
#
#            marital-status       occupation   relationship   race sex  \
# 8654        Never-married  Protective-serv  Not-in-family  White   M
# 15460  Married-civ-spouse   Prof-specialty        Husband  White   M
# 935    Married-civ-spouse     Craft-repair        Husband  White   M
# 26250  Married-civ-spouse  Farming-fishing        Husband  White   M
# 16992  Married-civ-spouse     Craft-repair        Husband  White   M
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 8654              0             0              99  United-States  <=50K
# ...

# %%
df.sort_values(by=['age', 'hours-per-week'], ascending=[True, False]).head(7)
# Out:
#        age  workclass  fnlwgt education  education-num marital-status  \
# 335     17    Private  270942   5th-6th              3  Never-married
# 4667    17    Private   48610      11th              7  Never-married
# 9971    17    Private  168807   7th-8th              4  Never-married
# 30898   17  Local-gov  192387       9th              5  Never-married
# 431     17          ?  202521      11th              7  Never-married
# 2105    17          ?  103810      12th              8  Never-married
# 2858    17          ?  179715      10th              6  Never-married
#
#             occupation    relationship   race sex  capital-gain  capital-loss  \
# 335      Other-service  Other-relative  White   M             0             0
# 4667   Farming-fishing       Own-child  White   M             0             0
# 9971      Craft-repair   Not-in-family  White   M             0             0
# 30898    Other-service       Own-child  White   M             0             0
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education-num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital-gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital-loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours-per-week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 hours-per-week
# age                   0.068756
# fnlwgt               -0.018768
# education-num         0.148123
# capital-gain          0.078409
# capital-loss          0.054256
# hours-per-week        1.000000

# %% [markdown]
# # Groupby

# %%
groups = df.groupby('education')

# %%
groups

# %%
groups.get_group('Bachelors')
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 4       28           Private  338409  Bachelors             13
# 9       42           Private  159449  Bachelors             13
# 11      30         State-gov  141297  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 32530   35                 ?  320084  Bachelors             13
# 32531   30                 ?   33811  Bachelors             13
# 32533   54           Private  337992  Bachelors             13
# 32536   34           Private  160216  Bachelors             13
# 32538   38           Private  139180  Bachelors             13
#
#            marital-status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
groups.age.mean().sort_values().plot(kind='barh')
# Out:
# <AxesSubplot: ylabel='education'>

# %%
groups['hours-per-week'].median()
# Out:
# education
# 10th            40.0
# 11th            40.0
# 12th            40.0
# 1st-4th         40.0
# 5th-6th         40.0
# 7th-8th         40.0
# 9th             40.0
# Assoc-acdm      40.0
# Assoc-voc       40.0
# Bachelors       40.0
# Doctorate       45.0
# HS-grad         40.0
# Masters         40.0
# Preschool       40.0
# Prof-school     48.0
# Some-college    40.0
# Name: hours-per-week, dtype: float64

# %%
groups.value_counts().to_frame()
# Out:
#                                                                                                                                                                                                   0
# education    age workclass        fnlwgt education-num marital-status     occupation        relationship   race               sex capital-gain capital-loss hours-per-week native-country salary
# 10th         17  ?                34019  6             Never-married      ?                 Own-child      White              M   0            0            20             United-States  <=50K   1
#              28  Private          73037  6             Never-married      Transport-moving  Unmarried      White              M   0            0            30             United-States  <=50K   1
#                                   221215 6             Never-married      Handlers-cleaners Other-relative White              M   0            0            40             Mexico         <=50K   1
# ...

# %% [markdown]
# **Agg**

# %%
groups.agg({'age': np.mean})
# Out:
#                     age
# education
# 10th          37.429796
# 11th          32.355745
# 12th          32.000000
# 1st-4th       46.142857
# 5th-6th       42.885886
# 7th-8th       48.445820
# 9th           41.060311
# Assoc-acdm    37.381443
# Assoc-voc     38.553546
# Bachelors     38.904949
# Doctorate     47.702179
# HS-grad       38.974479
# Masters       44.049913
# Preschool     42.764706
# Prof-school   44.746528
# Some-college  35.756275

# %%
age_df = groups.agg({'age': [min, max]})

# %%
age_df
# Out:
#              age
#              min max
# education
# 10th          17  90
# 11th          17  90
# 12th          17  79
# 1st-4th       19  90
# 5th-6th       17  84
# 7th-8th       17  90
# 9th           17  90
# Assoc-acdm    19  90
# Assoc-voc     19  84
# Bachelors     19  90
# Doctorate     24  80
# HS-grad       17  90
# Masters       18  90
# Preschool     19  75
# Prof-school   25  90
# Some-college  17  90

# %%
age_df['age']['min']
# Out:
# education
# 10th            17
# 11th            17
# 12th            17
# 1st-4th         19
# 5th-6th         17
# 7th-8th         17
# 9th             17
# Assoc-acdm      19
# Assoc-voc       19
# Bachelors       19
# Doctorate       24
# HS-grad         17
# Masters         18
# Preschool       19
# Prof-school     25
# Some-college    17
# Name: min, dtype: int64

# %%
age_df.columns
# Out:
# MultiIndex([('age', 'min'),
#             ('age', 'max')],
#            )

# %%
age_df.columns = age_df.columns.map(lambda x: '-'.join(x))

# %%
age_df
# Out:
#               age-min  age-max
# education
# 10th               17       90
# 11th               17       90
# 12th               17       79
# 1st-4th            19       90
# 5th-6th            17       84
# 7th-8th            17       90
# 9th                17       90
# Assoc-acdm         19       90
# Assoc-voc          19       84
# Bachelors          19       90
# Doctorate          24       80
# HS-grad            17       90
# Masters            18       90
# Preschool          19       75
# Prof-school        25       90
# Some-college       17       90

# %%
age_df.plot(kind='bar', figsize=(10, 8))
# Out:
# <AxesSubplot: xlabel='education'>

# %%
groups.agg({'age': [min, max], 'hours-per-week': np.median})
# Out:
#              age     hours-per-week
#              min max         median
# education
# 10th          17  90           40.0
# 11th          17  90           40.0
# 12th          17  79           40.0
# 1st-4th       19  90           40.0
# 5th-6th       17  84           40.0
# 7th-8th       17  90           40.0
# 9th           17  90           40.0
# Assoc-acdm    19  90           40.0
# Assoc-voc     19  84           40.0
# Bachelors     19  90           40.0
# Doctorate     24  80           45.0
# HS-grad       17  90           40.0
# Masters       18  90           40.0
# Preschool     19  75           40.0
# Prof-school   25  90           48.0
# Some-college  17  90           40.0

# %%
new_groups = df.groupby(['education', 'workclass', 'occupation'])

# %%
new_groups.mean().reset_index()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13536\1273744792.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_groups.mean().reset_index()
#         education    workclass        occupation        age         fnlwgt  \
# 0            10th            ?                 ?  33.980000  201144.460000
# 1            10th  Federal-gov      Craft-repair  59.750000  142961.750000
# 2            10th  Federal-gov     Other-service  43.500000  100235.000000
# 3            10th    Local-gov      Adm-clerical  54.500000  147426.000000
# 4            10th    Local-gov      Craft-repair  41.166667  145585.000000
# ..            ...          ...               ...        ...            ...
# 751  Some-college    State-gov             Sales  46.500000  148391.500000
# ...
